# %%
import pandas as pd

# %%
file = "SDCCD-Prop-S-N-Closeout-Checklist.xlsx"

# %%
file_df = pd.read_excel(file)
file_df.head(5)
# Out:
#      P Campus Proj #  FUSION #  \
# NaN  N   City  11110       NaN
# NaN  N   City  11240       NaN
# NaN  N   City  11250       NaN
# NaN  N   City  11260       NaN
# NaN  N   City  11310       NaN
#
#                                 Project Description  DSA  DSA_Count LEED  \
# NaN                             Humanities Building  Yes          1  TBD
# NaN                    Business Technology Building  Yes          1  TBD
# NaN  Engineering Technology Building ("T" Building)   No          1  TBD
# NaN                                Science Building   No          1  TBD
# NaN                          "M" Classroom Building  Yes          1  Yes
#
#      LEED_Count  GIS   ...     Unnamed: 49  Construction Complete?  \
# NaN           1  TBD   ...             1.0                     Yes
# NaN           1  TBD   ...             1.0                     Yes
# NaN           1  TBD   ...             0.0              Design/Bid
# ...

# %%
file_df.to_csv("SDCCD-Program-Close-Data.csv", index=False, header=True)
