# %%
import pandas as pd

# %%
file = "resource/SDCCD-Prop-S-N-Closeout-Checklist.xlsx"

# %%
file_df = pd.read_excel(file)
file_df.head(5)
# Out:
#      P Campus ProjectNumber  FUSION #  \
# NaN  N   City         11110       NaN
# NaN  N   City         11240       NaN
# NaN  N   City         11250       NaN
# NaN  N   City         11260       NaN
# NaN  N   City         11310       NaN
#
#                                  ProjectDescription  DSA  \
# NaN                             Humanities Building  Yes
# NaN                    Business Technology Building  Yes
# NaN  Engineering Technology Building ("T" Building)  Yes
# NaN                                Science Building   No
# NaN                          "M" Classroom Building  Yes
#
#                                              DSANumber LEED  \
# NaN                                          04-110503   No
# NaN                                          04-110503   No
# NaN                                          04-114494  Yes
# NaN  04-111042 (certified); 04-117766 (Alts to Scie...  Yes
# NaN                                          04-112843  Yes
#
#                                LEEDTarget RecordDrawings    ...     \
# NaN    Gold (still "in progress" 9/23/19)            Yes    ...
# NaN    Gold (still "in progress" 9/23/19)            Yes    ...
# NaN  Gold (62 points) achieved March 2019            Yes    ...
# NaN                                Silver            Yes    ...
# NaN                                Silver            Yes    ...
#
#     S - Ballot Reference # N - Ballot Reference # On Both Ballots Unnamed: 74  \
# NaN                  S.I.2                 N.II.1               x         NaN
# NaN                  S.I.3                  N.I.3               x         NaN
# NaN                  S.I.1                  N.I.2               x         NaN
# NaN               S.IV (?)                  N.I.1               x         NaN
# NaN                 S.IV.1                N.III.3               x         NaN
#
#     Unnamed: 75 Proj # Unnamed: 77 DSA_Count LEED_Count GIS_Count
# NaN         NaN  11110         NaN       1.0        1.0       1.0
# NaN         NaN  11240         NaN       1.0        1.0       1.0
# NaN         NaN  11250         NaN       1.0        1.0       1.0
# NaN         NaN  11260         NaN       1.0        1.0       1.0
# NaN         NaN  11310         NaN       1.0        1.0       1.0
#
# [5 rows x 81 columns]

# %%
file_df.to_csv("output/SDCCD-Program-Close-Data.csv", index=False, header=True)
